# %%
import sys
import pandas as pd
import unicodedata
from collections import defaultdict

unicode_category = defaultdict(list)
for c in map(chr, range(sys.maxunicode + 1)):
    unicode_category[unicodedata.category(c)].append(ord(c))

# %%
def get_ranges(l):
    ranges = []
    prev_x = 0
    
    for x in sorted(l):
        if not ranges:
            ranges.append([x])
        elif x - prev_x == 1:
            ranges[-1] = [ranges[-1][0], x]
        else:
            ranges.append([x])
        prev_x = x
        
    print(f"reduced {len(l)} ints to {len(ranges)} ranges")
    return ranges

def get_unicode_categories(*categories):
    output = []
    
    for category in categories:
        results = unicode_category[category]
        output.extend(results)
        print(f"{len(results)} for ${category}")
    
    return output

# %%
UnicodeLetter = get_unicode_categories('Lu', 'Ll', 'Lt', 'Lm', 'Lo', 'Nl')
UnicodeCombiningMark = get_unicode_categories('Mn', 'Mc')
UnicodeDigit = get_unicode_categories('Nd')
UnicodeConnectorPunctuation = get_unicode_categories('Pc')

ZWNJ = 0x200C
ZWJ = 0x200D

"""

    This implementation can safely ignore the 
    UnicodeEscapeSequence requirement as escape
    sequences are preprocessed out before the 
    Identifier checks.

    GRAMMAR:
    IdentifierStart ::
        UnicodeLetter
        $
        _
        \ UnicodeEscapeSequence
        
"""
IdentifierStart = [
    36, # $
    95, # _
    *UnicodeLetters
]

"""

    GRAMMAR:
    IdentifierPart ::
        IdentifierStart
        UnicodeCombiningMark
        UnicodeDigit
        UnicodeConnectorPunctuation
        <ZWNJ>
        <ZWJ>
        
"""
IdentifierPart = [
    *IdentifierStart,
    *UnicodeCombiningMark,
    *UnicodeDigit,
    *UnicodeConnectorPunctuation,
    ZWNJ,
    ZWJ
]
# Out:
# 1788 for $Lu
# 2151 for $Ll
# 31 for $Lt
# 259 for $Lm
# 121414 for $Lo
# 236 for $Nl
# 1826 for $Mn
# 429 for $Mc
# 630 for $Nd
# 10 for $Pc

# %%
IdentifierPartRanges = get_ranges(IdentifierPart)
nRanges = len(IdentifierPartRanges)

output = ""
i = 0
for charRange in IdentifierPartRanges:
    charRange = [hex(char) for char in charRange]
    if len(charRange) == 1:
        output += f"(ch == {charRange[0]})"
    else:
        output += f"({charRange[0]} <= ch & ch <= {charRange[1]})"
        
    i += 1
    if (i < nRanges):
        output += "|"
        

print(f"\n({output})")
# Out:
# reduced 128778 ints to 718 ranges
#
# ((ch == 0x24)|(0x30 <= ch & ch <= 0x39)|(0x41 <= ch & ch <= 0x5a)|(ch == 0x5f)|(ch == 0x5f)|(0x61 <= ch & ch <= 0x7a)|(ch == 0xaa)|(ch == 0xb5)|(ch == 0xba)|(0xc0 <= ch & ch <= 0xd6)|(0xd8 <= ch & ch <= 0xf6)|(0xf8 <= ch & ch <= 0x2c1)|(0x2c6 <= ch & ch <= 0x2d1)|(0x2e0 <= ch & ch <= 0x2e4)|(ch == 0x2ec)|(ch == 0x2ee)|(0x300 <= ch & ch <= 0x374)|(0x376 <= ch & ch <= 0x377)|(0x37a <= ch & ch <= 0x37d)|(ch == 0x37f)|(ch == 0x386)|(0x388 <= ch & ch <= 0x38a)|(ch == 0x38c)|(0x38e <= ch & ch <= 0x3a1)|(0x3a3 <= ch & ch <= 0x3f5)|(0x3f7 <= ch & ch <= 0x481)|(0x483 <= ch & ch <= 0x487)|(0x48a <= ch & ch <= 0x52f)|(0x531 <= ch & ch <= 0x556)|(ch == 0x559)|(0x560 <= ch & ch <= 0x588)|(0x591 <= ch & ch <= 0x5bd)|(ch == 0x5bf)|(0x5c1 <= ch & ch <= 0x5c2)|(0x5c4 <= ch & ch <= 0x5c5)|(ch == 0x5c7)|(0x5d0 <= ch & ch <= 0x5ea)|(0x5ef <= ch & ch <= 0x5f2)|(0x610 <= ch & ch <= 0x61a)|(0x620 <= ch & ch <= 0x669)|(0x66e <= ch & ch <= 0x6d3)|(0x6d5 <= ch & ch <= 0x6dc)|(0x6df <= ch & ch <= 0x6e8)|(0x6ea <= ch & ch <= 0x6fc)|(ch == 0x6ff)|(0x710 <= ch & ch <= 0x74a)|(0x74d <= ch & ch <= 0x7b1)|(0x7c0 <= ch & ch <= 0x7f5)|(ch == 0x7fa)|(ch == 0x7fd)|(0x800 <= ch & ch <= 0x82d)|(0x840 <= ch & ch <= 0x85b)|(0x860 <= ch & ch <= 0x86a)|(0x8a0 <= ch & ch <= 0x8b4)|(0x8b6 <= ch & ch <= 0x8bd)|(0x8d3 <= ch & ch <= 0x8e1)|(0x8e3 <= ch & ch <= 0x963)|(0x966 <= ch & ch <= 0x96f)|(0x971 <= ch & ch <= 0x983)|(0x985 <= ch & ch <= 0x98c)|(0x98f <= ch & ch <= 0x990)|(0x993 <= ch & ch <= 0x9a8)|(0x9aa <= ch & ch <= 0x9b0)|(ch == 0x9b2)|(0x9b6 <= ch & ch <= 0x9b9)|(0x9bc <= ch & ch <= 0x9c4)|(0x9c7 <= ch & ch <= 0x9c8)|(0x9cb <= ch & ch <= 0x9ce)|(ch == 0x9d7)|(0x9dc <= ch & ch <= 0x9dd)|(0x9df <= ch & ch <= 0x9e3)|(0x9e6 <= ch & ch <= 0x9f1)|(ch == 0x9fc)|(ch == 0x9fe)|(0xa01 <= ch & ch <= 0xa03)|(0xa05 <= ch & ch <= 0xa0a)|(0xa0f <= ch & ch <= 0xa10)|(0xa13 <= ch & ch <= 0xa28)|(0xa2a <= ch & ch <= 0xa30)|(0xa32 <= ch & ch <= 0xa33)|(0xa35 <= ch & ch <= 0xa36)|(0xa38 <= ch & ch <= 0xa39)|(ch == 0xa3c)|(0xa3e <= ch & ch <= 0xa42)|(0xa47 <= ch & ch <= 0xa48)|(0xa4b <= ch & ch <= 0xa4d)|(ch == 0xa51)|(0xa59 <= ch & ch <= 0xa5c)|(ch == 0xa5e)|(0xa66 <= ch & ch <= 0xa75)|(0xa81 <= ch & ch <= 0xa83)|(0xa85 <= ch & ch <= 0xa8d)|(0xa8f <= ch & ch <= 0xa91)|(0xa93 <= ch & ch <= 0xaa8)|(0xaaa <= ch & ch <= 0xab0)|(0xab2 <= ch & ch <= 0xab3)|(0xab5 <= ch & ch <= 0xab9)|(0xabc <= ch & ch <= 0xac5)|(0xac7 <= ch & ch <= 0xac9)|(0xacb <= ch & ch <= 0xacd)|(ch == 0xad0)|(0xae0 <= ch & ch <= 0xae3)|(0xae6 <= ch & ch <= 0xaef)|(0xaf9 <= ch & ch <= 0xaff)|(0xb01 <= ch & ch <= 0xb03)|(0xb05 <= ch & ch <= 0xb0c)|(0xb0f <= ch & ch <= 0xb10)|(0xb13 <= ch & ch <= 0xb28)|(0xb2a <= ch & ch <= 0xb30)|(0xb32 <= ch & ch <= 0xb33)|(0xb35 <= ch & ch <= 0xb39)|(0xb3c <= ch & ch <= 0xb44)|(0xb47 <= ch & ch <= 0xb48)|(0xb4b <= ch & ch <= 0xb4d)|(0xb56 <= ch & ch <= 0xb57)|(0xb5c <= ch & ch <= 0xb5d)|(0xb5f <= ch & ch <= 0xb63)|(0xb66 <= ch & ch <= 0xb6f)|(ch == 0xb71)|(0xb82 <= ch & ch <= 0xb83)|(0xb85 <= ch & ch <= 0xb8a)|(0xb8e <= ch & ch <= 0xb90)|(0xb92 <= ch & ch <= 0xb95)|(0xb99 <= ch & ch <= 0xb9a)|(ch == 0xb9c)|(0xb9e <= ch & ch <= 0xb9f)|(0xba3 <= ch & ch <= 0xba4)|(0xba8 <= ch & ch <= 0xbaa)|(0xbae <= ch & ch <= 0xbb9)|(0xbbe <= ch & ch <= 0xbc2)|(0xbc6 <= ch & ch <= 0xbc8)|(0xbca <= ch & ch <= 0xbcd)|(ch == 0xbd0)|(ch == 0xbd7)|(0xbe6 <= ch & ch <= 0xbef)|(0xc00 <= ch & ch <= 0xc0c)|(0xc0e <= ch & ch <= 0xc10)|(0xc12 <= ch & ch <= 0xc28)|(0xc2a <= ch & ch <= 0xc39)|(0xc3d <= ch & ch <= 0xc44)|(0xc46 <= ch & ch <= 0xc48)|(0xc4a <= ch & ch <= 0xc4d)|(0xc55 <= ch & ch <= 0xc56)|(0xc58 <= ch & ch <= 0xc5a)|(0xc60 <= ch & ch <= 0xc63)|(0xc66 <= ch & ch <= 0xc6f)|(0xc80 <= ch & ch <= 0xc83)|(0xc85 <= ch & ch <= 0xc8c)|(0xc8e <= ch & ch <= 0xc90)|(0xc92 <= ch & ch <= 0xca8)|(0xcaa <= ch & ch <= 0xcb3)|(0xcb5 <= ch & ch <= 0xcb9)|(0xcbc <= ch & ch <= 0xcc4)|(0xcc6 <= ch & ch <= 0xcc8)|(0xcca <= ch & ch <= 0xccd)|(0xcd5 <= ch & ch <= 0xcd6)|(ch == 0xcde)|(0xce0 <= ch & ch <= 0xce3)|(0xce6 <= ch ...
